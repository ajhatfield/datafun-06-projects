# %% [markdown]
# # Unique Project - basketball domain
#
# ## Author: Alison Hatfield
# ## Date : Sep 2023

# %% [markdown]
# ### Section 1-Load - Read from a data file into a pandas DataFrame.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('basketball.csv', index_col=0)

# %% [markdown]
# ### Section 2-View - Display the first 5 rows and the last 5 rows.

# %%
df.head()
# Out:
#         Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1          86   4385         2762      1647         552        563
# Team 2          86   4262         2762      1581         573        608
# Team 3          80   3442         2614      1241         598        775
# Team 4          82   3386         2664      1187         616        861
# Team 5          86   3368         2762      1209         633        920
#
#         BasketScored  BasketGiven  TournamentChampion  Runner-up TeamLaunch  \
# Team
# Team 1          5947         3140                  33         23       1929
# Team 2          5900         3114                  25         25       1929
# Team 3          4534         3309                  10          8       1929
# Team 4          4398         3469                   6          6   1931to32
# Team 5          4631         3700                   8          7       1929
#
#         HighestPositionHeld
# Team
# ...

# %%
df.tail()
# Out:
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 57           1     34           38         8          10         20
# Team 58           1     22           30         7           8         15
# Team 59           1     19           30         7           5         18
# Team 60           1     14           30         5           4         21
# Team 61           1      0            0         0           0          0
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up TeamLaunch  \
# Team
# Team 57            38           66                   0          0    2009-10
# Team 58            37           57                   0          0    1956-57
# Team 59            51           85                   0          0    1951~52
# Team 60            34           65                   0          0    1955-56
# Team 61             0            0                   0          0    2017~18
#
#          HighestPositionHeld
# Team
# ...

# %% [markdown]
# ### Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns.

# %%
df.describe()
# Out:
#        Tournament        Score  PlayedGames     WonGames  DrawnGames  \
# count   61.000000    61.000000    61.000000    61.000000   61.000000
# mean    24.000000   901.426230   796.819672   303.967213  188.934426
# std     26.827225  1134.899121   876.282765   406.991030  201.799477
# min      1.000000     0.000000     0.000000     0.000000    0.000000
# 25%      4.000000    96.000000   114.000000    34.000000   24.000000
# 50%     12.000000   375.000000   423.000000   123.000000   95.000000
# 75%     38.000000  1351.000000  1318.000000   426.000000  330.000000
# max     86.000000  4385.000000  2762.000000  1647.000000  633.000000
#
#          LostGames  BasketScored  BasketGiven  TournamentChampion  Runner-up  \
# count    61.000000     61.000000    61.000000           61.000000  61.000000
# mean    303.754098   1140.344262  1140.229508            1.426230   1.409836
# std     294.708594   1506.740211  1163.710766            5.472535   4.540107
# ...

# %% [markdown]
# ### Section 4-Series: Use the Series method describe() to calculate the descriptive stats for all category/text columns

# %%
df.describe(exclude=[np.number])
# Out:
#        TeamLaunch
# count          61
# unique         47
# top          1929
# freq           10

# %% [markdown]
# ### Section 5-Unique: Use the Series method unique() to get unique category values.

# %%
(df.TeamLaunch).unique()
# Out:
# array(['1929', '1931to32', '1934-35', '1939-40', '1932-33', '1941to42',
#        '1948-49', '1944_45', '1935-36', '1949_50', '1933to34', '1960-61',
#        '1951-52', '1998-99', '1941-42', '1977-78', '1959-60', '2004to05',
#        '1961-62', '1940-41', '1930-31', '1963-64', '1974-75', '1943-44',
#        '1987-88', '1991_92', '2007-08', '1962-63', '1994-95', '1978-79',
#        '1971-72', '1999to00', '2014-15', '1990-91', '1947-48', '1996-97',
#        '1995-96', '1945-46', '1953-54', '1979-80', '1950-51', '2016_17',
#        '2009-10', '1956-57', '1951~52', '1955-56', '2017~18'],
#       dtype=object)

# %% [markdown]
# ### Section 6-Histograms: Use the DataFrame's hist() function to create a histogram for each numerical column.

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Tournament'}>,
#         <Axes: title={'center': 'Score'}>,
#         <Axes: title={'center': 'PlayedGames'}>],
#        [<Axes: title={'center': 'WonGames'}>,
#         <Axes: title={'center': 'DrawnGames'}>,
#         <Axes: title={'center': 'LostGames'}>],
#        [<Axes: title={'center': 'BasketScored'}>,
#         <Axes: title={'center': 'BasketGiven'}>,
#         <Axes: title={'center': 'TournamentChampion'}>],
#        [<Axes: title={'center': 'Runner-up'}>,
#         <Axes: title={'center': 'HighestPositionHeld'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Section 7-List: Get some of your information into a list. Process each item in the list (use for or comprehensions as you like).

# %%
WonGames = df['WonGames'].to_list()
LostGames = df['LostGames'].to_list()
DrawnGames = df['DrawnGames'].to_list()

# %% [markdown]
# ### Section 8-Filter: Use filter() to show only part of the information.

# %%
# Teams who have won more than 5 games

list(filter(lambda x: x > 5, WonGames))
# Out:
# [1647,
#  1581,
#  1241,
#  1187,
#  1209,
#  990,
#  948,
#  864,
#  698,
#  606,
#  563,
#  586,
#  463,
#  453,
#  471,
#  426,
#  390,
#  408,
#  333,
#  367,
#  266,
#  218,
#  189,
#  203,
#  147,
#  184,
#  155,
#  145,
#  125,
#  113,
#  123,
#  129,
#  104,
#  96,
#  103,
#  76,
#  62,
#  82,
#  52,
#  50,
#  59,
#  53,
#  37,
#  35,
#  43,
#  26,
#  34,
#  20,
#  19,
#  30,
#  29,
#  21,
#  17,
#  18,
#  13,
#  8,
#  8,
#  7,
#  7]

# %% [markdown]
# ### Section 9-Map: Use map() to transform some of the data.

# %%
# map each GamesWon to x2 to simulate same results in next tournament

list(map(lambda x: x * 2, WonGames))
# Out:
# [3294,
#  3162,
#  2482,
#  2374,
#  2418,
#  1980,
#  1896,
#  1728,
#  1396,
#  1212,
#  1126,
#  1172,
#  926,
#  906,
#  942,
#  852,
#  780,
#  816,
#  666,
#  734,
#  532,
#  436,
#  378,
#  406,
#  294,
#  368,
#  310,
#  290,
#  250,
#  226,
#  246,
#  258,
#  208,
#  192,
#  206,
#  152,
#  124,
#  164,
#  104,
#  100,
#  118,
#  106,
#  74,
#  70,
#  86,
#  52,
#  68,
#  40,
#  38,
#  60,
#  58,
#  42,
#  34,
#  36,
#  26,
#  16,
#  16,
#  14,
#  14,
#  10,
#  0]
